# %%
import os
os.chdir("D:\\DATA SCIENCE\\TEMAS\\INTRODUCCIÓN\\")
from IPython.display import Image

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'imagenes', 'INTRODUCCIÓN.ipynb']

# %% [markdown]
# ### DATA SCIENCE

# %% [markdown]
# "Data Science es la ciencia centrada en el estudio de los datos. Se encarga de extraer información de grandes cantidades de datos. Data Science combina la estadística, las matemáticas y la informática para interpretar datos. El objetivo es tomar decisiones."

# %% [markdown]
# [1](https://www.kdnuggets.com/2017/08/data-science-primer-basic-concepts-for-beginners.html)
# [2](https://searchenterpriseai.techtarget.com/definition/data-science)
# [3](https://blog.dataiku.com/an-introduction-to-key-data-science-concepts)
# [4](https://www.omnisci.com/learn/data-science)
# [5](https://www.oreilly.com/library/view/doing-data-science/9781449363871/ch01.html)
# [6](https://365datascience.com/career-advice/career-guides/defining-data-science/)
# [7](https://intellipaat.com/blog/what-is-data-science/)
# [8](https://www.bernardmarr.com/default.asp?contentID=1446)
# [9](https://www.kaggle.com/xiuwenbo666/data-science-methodology)
# [10](https://www.ibmbigdatahub.com/blog/why-we-need-methodology-data-science)
# [11](https://www.kdnuggets.com/2014/10/crisp-dm-top-methodology-analytics-data-mining-data-science-projects.html)

# %% [markdown]
# ### MACHINE LEARNING

# %% [markdown]
# [1](https://www.grapheverywhere.com/machine-learning-que-es-tipos-ejemplos-y-como-implementarlo/)
# [2](https://www.analyticsvidhya.com/blog/2015/06/machine-learning-basics/)
# [3](https://www.apd.es/algoritmos-del-machine-learning/)
# [4](https://machinelearningmastery.com/basic-concepts-in-machine-learning/#:~:text=Machine%20learning%20is%20the%20way,be%20used%20in%20traditional%20programming.)
# [5](https://docs.microsoft.com/en-us/azure/machine-learning/algorithm-cheat-sheet)
# ["1"](https://www.r-bloggers.com/2019/07/101-machine-learning-algorithms-for-data-science-with-cheat-sheets/)
# ["2"](https://medium.com/machine-learning-in-practice/cheat-sheet-of-machine-learning-and-python-and-math-cheat-sheets-a4afe4e791b6)
# ["3"](https://blogs.sas.com/content/subconsciousmusings/2020/12/09/machine-learning-algorithm-use/)
# [6](https://hardzone.es/ofertas/pc-componentes/memoria-ram-rgb-febrero-2021/)
# [7](https://blogs.oracle.com/bigdata/difference-ai-machine-learning-deep-learning)
# [8](https://www.ibm.com/cloud/blog/ai-vs-machine-learning-vs-deep-learning-vs-neural-networks)
# [9](https://www.xataka.com/robotica-e-ia/machine-learning-y-deep-learning-como-entender-las-claves-del-presente-y-futuro-de-la-inteligencia-artificial)
# [10](https://medium.com/ai-in-plain-english/artificial-intelligence-vs-machine-learning-vs-deep-learning-whats-the-difference-dccce18efe7f)

# %%
Image(filename='imagenes/algoritmos_1.jpg')

# %%
Image(filename='imagenes/algoritmos_2.jpg')

# %%
Image(filename='imagenes/algoritmos_3.jpg')

# %%
Image(filename='imagenes/algoritmos_4.jpg')

# %%
Image(filename='imagenes/algoritmos_5.jpg')

# %%
Image(filename='imagenes/algoritmos_6.jpg')

# %% [markdown]
# ### CRIPS-DM, SEMMA Y KDD

# %% [markdown]
# [1](https://disi.unal.edu.co/~eleonguz/cursos/md/presentaciones/Sesion5_Metodologias.pdf)
# [2](https://core.ac.uk/download/pdf/229036986.pdf)
# [3](https://www.kdnuggets.com/2016/03/data-science-process-rediscovered.html/2)
# [4](https://www.sciencedirect.com/science/article/pii/S2212827119302239)
# [5](https://www.quora.com/Which-is-the-older-methodology-for-data-mining-crisp-DM-or-Semma)
# [6](https://docplayer.net/43906965-Kdd-semma-and-crisp-dm-a-parallel-overview.html)

# %% [markdown]
# Documentar un proyecto crips

# %% [markdown]
# ### APRENDIZAJE SUPERVISADO

# %% [markdown]
# #### REGRESIÓN LOGÍSTICA

# %% [markdown]
# [1](https://realpython.com/logistic-regression-python/)
# [2](https://www.datacamp.com/community/tutorials/understanding-logistic-regression-python)
# [3](https://towardsdatascience.com/building-a-logistic-regression-in-python-step-by-step-becd4d56c9c8)
# [4](https://beckernick.github.io/logistic-regression-from-scratch/)
# [5](https://www.geeksforgeeks.org/implementation-of-logistic-regression-from-scratch-using-python/)
# [6](https://www.kaggle.com/jeppbautista/logistic-regression-from-scratch-python)
# [7](https://medium.com/@martinpella/logistic-regression-from-scratch-in-python-124c5636b8ac)
# [8](https://www.kdnuggets.com/2019/10/build-logistic-regression-model-python.html)
# [9](https://www.youtube.com/watch?v=JDU3AzH3WKg)
# [10](https://rickwierenga.com/blog/ml-fundamentals/logistic-regression.html)
# [11](https://dhirajkumarblog.medium.com/logistic-regression-in-python-from-scratch-5b901d72d68e)
# [12](https://github.com/trekhleb/homemade-machine-learning/tree/master/homemade/logistic_regression)
# ["1"](https://www.reneshbedre.com/blog/logistic-regression.html)

# %% [markdown]
# #### ÁRBOL DE DECISIONES

# %% [markdown]
# [1](https://www.datacamp.com/community/tutorials/decision-tree-classification-python)
# [2](https://www.python-course.eu/Decision_Trees.php)
# [3](https://www.analyticsvidhya.com/blog/2020/10/all-about-decision-tree-from-scratch-with-python-implementation/)
# [4](https://dhirajkumarblog.medium.com/decision-tree-from-scratch-in-python-629631ec3e3a)
# [5]()
# [6]()
# [7]()
# [8]()
# [9]()
# [10]()

# %% [markdown]
# ### APRENDIZAJE NO SUPERVISADO

# %% [markdown]
# #### K-MEANS

# %% [markdown]
# [1](https://www.aprendemachinelearning.com/k-means-en-python-paso-a-paso/)
# [2](https://realpython.com/k-means-clustering-python/#:~:text=The%20k%2Dmeans%20clustering%20method,the%20oldest%20and%20most%20approachable.)
# [3](https://www.machinelearningplus.com/predictive-modeling/k-means-clustering/)
# [4](https://medium.com/machine-learning-algorithms-from-scratch/k-means-clustering-from-scratch-in-python-1675d38eee42)
# [5](https://dev.to/rishitdagli/build-k-means-from-scratch-in-python-2140)
# [6](https://www.linkedin.com/pulse/clustering-using-k-means-python-from-scratch-venkata-sai-nikhila)
# [7](https://gdcoder.com/implementation-of-k-means-from-scratch-in-python-9-lines/)
# [8](https://pythonprogramming.net/k-means-from-scratch-machine-learning-tutorial/)
# [9](https://mmuratarat.github.io/2019-07-23/kmeans_from_scratch)
# [10](https://www.analyticsvidhya.com/blog/2019/08/comprehensive-guide-k-means-clustering/)
# [11](https://aihubprojects.com/k-means-clustering-from-scratch-python/)
# [12](https://towardsai.net/p/machine-learning/k-means-clustering-from-scratch)
# [13](http://madhugnadig.com/articles/machine-learning/2017/03/04/implementing-k-means-clustering-from-scratch-in-python.html)
# [14](https://dfrieds.com/machine-learning/k-means-from-scratch-python.html)
# [15](https://www.kdnuggets.com/2017/06/machine-learning-workflows-python-scratch-part-2.html)
# [16](https://johnnykoo.dev/article/en/implement-k-means-clustering/)
# [17](https://www.askpython.com/python/examples/k-means-clustering-from-scratch)
# [18](https://automaticaddison.com/k-means-clustering-algorithm-from-scratch-machine-learning/)
#
# *https://www.youtube.com/watch?v=GmXSwe-5OXk
# *https://www.youtube.com/watch?v=EiYh0D4UJrI
# *https://www.youtube.com/watch?v=JZSYll1j6QA

# %% [markdown]
# #### PCA

# %% [markdown]
# [1](https://www.datacamp.com/community/tutorials/principal-component-analysis-in-python)
# [2](https://towardsdatascience.com/pca-using-python-scikit-learn-e653f8989e60)
# [3](https://stackabuse.com/implementing-pca-in-python-with-scikit-learn/)
# [4](https://medium.com/towards-artificial-intelligence/principal-component-analysis-pca-with-python-examples-tutorial-67a917bae9aa)
# [5](https://www.askpython.com/python/examples/principal-component-analysis)
# [6](https://stackoverflow.com/questions/13224362/principal-component-analysis-pca-in-python)
# [7](https://www.cienciadedatos.net/documentos/py19-pca-python.html)
# [8](https://www.askpython.com/python/examples/principal-component-analysis)
# [9](https://drscotthawley.github.io/blog/2019/12/21/PCA-From-Scratch.html)
# [10](http://www.oranlooney.com/post/ml-from-scratch-part-6-pca/)
# [11](https://www.kdnuggets.com/2020/05/dimensionality-reduction-principal-component-analysis.html)
# [12](https://sebastianraschka.com/Articles/2014_pca_step_by_step.html)
# [13](https://www.codecademy.com/articles/principal-component-analysis-intro)

# %% [markdown]
# #### ANÁLISIS FACTORIAL

# %% [markdown]
# [1](https://www.datacamp.com/community/tutorials/introduction-factor-analysis)
# [2](https://educationalresearchtechniques.com/2018/10/24/factor-analysis-in-python/)
# [3](https://www.analyticsvidhya.com/blog/2020/10/dimensionality-reduction-using-factor-analysis-in-python/)
# [4](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6010767/)
# [5](https://www.youtube.com/watch?v=ttBs_wfw_6U)
# [6](https://www.youtube.com/watch?v=Lzv7GpGpbSM)
# [7]()
# [8]()
# [9]()
# [10](http://www.di.fc.ul.pt/~jpn/r/factoranalysis/factoranalysis.html)
# [11](https://www.cs.helsinki.fi/u/sakaya/tutorial/)
# [12]()

# %% [markdown]
# ["1"](https://morioh.com/p/533381b729fe)
# ["2"](https://www.kaggle.com/kashnitsky/topic-9-part-1-time-series-analysis-in-python)

# %% [markdown]
# ### CASOS DE USO

# %% [markdown]
# #### MODELO CHURN

# %% [markdown]
# [1](https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0191-6)
# [2](https://core.ac.uk/download/pdf/83461632.pdf)
# [3](https://www.kdnuggets.com/2019/05/churn-prediction-machine-learning.html)
# [4](file:///C:/Users/OMAR/Downloads/Improvised_XgBoost_Machine_learning_Algorithm_for_.pdf)
# [5](file:///C:/Users/OMAR/Downloads/churnBoostingV2.pdf)
# [6](https://www.tesisenred.net/bitstream/handle/10803/144660/TDGG1de1.pdf?sequence=1&isAllowed=y)
# [7](https://algorithmia.com/blog/customer-churn-prediction-with-machine-learning)
# [8](file:///C:/Users/OMAR/Downloads/Defection_Detection_Measuring_and_Understanding_th.pdf)
# [9](https://lib.dr.iastate.edu/cgi/viewcontent.cgi?referer=&httpsredir=1&article=7030&context=etd)
# [10](https://sci-hub.st/https://www.sciencedirect.com/science/article/abs/pii/S0957417408004326)
# [11](https://sci-hub.st/https://link.springer.com/article/10.1007/s10115-016-0995-z)
# [12](https://gvpress.com/journals/IJMUE/vol10_no7/22.pdf)
# [13](https://arxiv.org/ftp/arxiv/papers/1607/1607.07792.pdf)
# [14](https://dimensionless.in/how-to-train-decision-tree-classifier-for-churn-prediction/)
# [15](https://d1wqtxts1xzle7.cloudfront.net/47097857/A_Proposed_Churn_Prediction_Model20160707-17047-cdvpeo.pdf?1467957002=&response-content-disposition=inline%3B+filename%3DA_Proposed_Churn_Prediction_Model.pdf&Expires=1613684262&Signature=YZP6s~4Lcov7SFsAnJxMgiLeRICvaQ8NwKQLAhVYNvYHYmkrVtOllaEyGuBMEPYsLjnB~lBwpiMjbDN1X5sfU1kE4phy-ndsTkYUJnulQMPBbB2ftN3E4zHtwXQxtDS3wn1oRCw-cJl8wxoMNhlOE9ph~-bvEAq0AbDshC7~-EWDztnYLaCCPrTLdXrHCHaaBl5remGiUlEkRhj0Rkej~2y2iUX5SASBKBbNWIhI1nnO6s2lnm3RZoqSFtNBJmQiIWaA3Q-4fofOGQLGpQ4keznrsOy~IVXjNXYu2hmxZzGBV-ELHP-FEPGUx21UpMck7q2iNr7kcYvWSFtaXog8kw__&Key-Pair-Id=APKAJLOHF5GGSLRBV4ZA)
# [16](https://personal.utdallas.edu/~nicholas.ruozzi/cs7301/2016fa/lects/Lecture_6_Decision.pdf)
# [17](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.462.7201&rep=rep1&type=pdf)

# %% [markdown]
# * qué algotirmos son los más utilizados?
# * qué oportunidades de mejora existen?
# * qué planes de implementación existen?

# %% [markdown]
# #### MODELO FIDELIZACIÓN

# %% [markdown]
# #### MODELO DE PROPENSIÓN A LA COMPRA

# %% [markdown]
# ### CUSTOMER JOURNEY

# %%
Image(filename='imagenes/journey_1.jpg')

# %%
Image(filename='imagenes/journey_3.jpg')

# %%
Image(filename='imagenes/journey_2.jpg')

# %% [markdown]
# [1](https://www.forbes.com/sites/danielnewman/2020/12/30/ai-and-analytics-optimizing-your-digital-customer-journey-map/?sh=4dcc81881f49)
# [2](https://monkeylearn.com/blog/machine-learning-on-the-customer-journey/)
# [3](https://www.cmswire.com/digital-experience/how-machine-learning-improves-customer-journey-mapping/)
# [4](https://qymatix.de/en/b2b-customer-journey-predictive-analytics/)
# []()
# []()
# []()

# %% [markdown]
# ### OBSERVACIONES

# %% [markdown]
# #### PYSPARK - SQL

# %% [markdown]
# []()
# []()
# []()
# []()
# []()
# []()
# []()
# []()

# %% [markdown]
# #### ETL

# %% [markdown]
# [](https://medium.com/analytics-vidhya/etl-pipeline-using-spark-sql-746bbfae4d03)
# [](https://www.youtube.com/watch?v=exWGf0aXJF4&feature=emb_logo)
# []()
# []()
# []()
# []()
# []()
# []()
